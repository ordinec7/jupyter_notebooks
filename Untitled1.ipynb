# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from copy import deepcopy

from math import pi, cos, sin, sqrt, tan, acos
import numpy as np
from numpy import array, zeros, arange
from numpy import concatenate as np_concat
from numpy import real
from numpy.linalg import eig as eigenvalues
import matplotlib.pyplot as plt

from calculate_system import EquationCalculator
from progress_bar import ProgressBar
from create_fig import *
from function_root_finder import roots
from log_progress import log_progress

from collections import defaultdict


from matplotlib import animation, rc
from IPython.display import HTML

from random import random as rnd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def harm(xs, i):
    return np.sin(pi * i * xs)

# %%
# fig = create_fig()

# xs = arange(0, 1.1, 0.01)
# plt.axis([0, 1, -2, 2])
# plt.grid()

# plt.ion()

# for i in arange(0, 10, 0.1):
#     plt.plot(xs, array([harm(x, 1) for x in xs]) * cos(i), "b-")
#     plt.pause(0.05)
    
    
fig, ax = plt.subplots()

ax.set_xlim(( 0, 1))
ax.set_ylim((-4, 4))

line, = ax.plot([], [], lw=2)

# %%
def init():
    line.set_data([], [])
    return (line,)

# %%
# animation function. This is called sequentially

xs = arange(0, 1.01, 0.001)
phs = [0]
for i in range(500):
    phs.append(phs[i] + 0 * rnd())

def animate(i):
    
    ys = zeros(len(xs))
    for j in range(1, 500):
        
        a = cos(phs[j-1] + 4 * pi * i / 100.0 * j) / (1.5**(j-1))
        ys += harm(xs, j) * a
    
    
    line.set_data(xs, ys)
    return (line,)

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# %%
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...
